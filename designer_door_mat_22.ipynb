# %%
N,M=map(int,input().split())

# %%
print(N)
# Out:
# 7

# %%
N
# Out:
# 7

# %%
print(M)
# Out:
# 21

# %%
'.|.'.center(7)
# Out:
# '  .|.  '

# %%
'.|.'.center(21)
# Out:
# '         .|.         '

# %%
#we can also fill the empty space
'.|.'.center(21,'-')
# Out:
# '---------.|.---------'

# %%
('.|.' * 3).center(21,'-')
# Out:
# '------.|..|..|.------'

# %%
('.|.' * 5).center(21,'-')
# Out:
# '---.|..|..|..|..|.---'

# %%
list(range(1,N,2))
# Out:
# [1, 3, 5]

# %%
#top part
for i in range(1,N,2):
  print(('.|.' * i).center(M,'-'))
# Out:
# ---------.|.---------
# ------.|..|..|.------
# ---.|..|..|..|..|.---

# %%
for i in range(N-2,-1,-2):
  print (i)
# Out:
# 5
# 3
# 1

# %%
list(range(N-2,-1,-2))
# Out:
# [5, 3, 1]

# %%
#bottom part
for i in range(N-2,-1,-2):
  print(('.|.' * i).center(M,'-'))
# Out:
# ---.|..|..|..|..|.---
# ------.|..|..|.------
# ---------.|.---------

# %%
#top part with welcome wrttien
for i in range(1,N,2):
  print(('.|.' * i).center(M,'-'))
print('WELCOME'.center(M,'-'))
# Out:
# ---------.|.---------
# ------.|..|..|.------
# ---.|..|..|..|..|.---
# -------WELCOME-------

# %%
# So final code

def doormat(N,M):
  for i in range(1,N,2):
    print(('.|.' * i).center(M,'-'))
  print('WELCOME'.center(M,'-'))

  for j in range(N-2,-1,-2):
    print(('.|.'*j).center(M,'-'))
    
N,M=map(int,input().split())
doormat(N,M)
# Out:
# ---------.|.---------
# ------.|..|..|.------
# ---.|..|..|..|..|.---
# -------WELCOME-------
# ---.|..|..|..|..|.---
# ------.|..|..|.------
# ---------.|.---------
