# %%
my_list=[]

# %%
my_list.insert(0,5)

# %%
my_list.insert(1,10)

# %%
my_list.insert(0,6)

# %%
print(my_list)
# Out:
# [6, 5, 10]

# %%
my_list.remove(6)

# %%
my_list.append(9)

# %%
my_list.append(1)

# %%
my_list.sort()

# %%
print(my_list)
# Out:
# [1, 5, 9, 10]

# %%
my_list.pop()
# Out:
# 10

# %%
my_list.reverse()

# %%
print(my_list)
# Out:
# [9, 5, 1]

# %%
user_input=input().split()

# %%
user_input
# Out:
# ['insert', '2', '3', '5']

# %%
user_input[0]
# Out:
# 'insert'

# %%
user_input[1]
# Out:
# '2'

# %%
user_input[2]
# Out:
# '3'
