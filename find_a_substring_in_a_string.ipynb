# %%
string='ABCDCDC'

# %%
sub_string='CDC'

# %%
len(string)
# Out:
# 7

# %%
len(sub_string)
# Out:
# 3

# %%
n=len(sub_string)
count=0
for i in range(len(string)):
    if string[i:i+n] == sub_string[0:]:
        count+=1
print(count)
# Out:
# 2
