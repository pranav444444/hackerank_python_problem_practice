# %%
a="this is a string"

# %%
print(a)
# Out:
# this is a string

# %%
# delimmeter split is used to separate the string based on input..it can be space,'/','-' or anything
# string will get converted into lists
b=a.split(" ")
print(b)
# Out:
# ['this', 'is', 'a', 'string']

# %% [markdown]
# ''.join() means make an empty stinf and join all the eleemnts present in b

# %%
''.join(b)
# Out:
# 'thisisastring'

# %% [markdown]
# join elements of b using '-'

# %%
'-'.join(b)
# Out:
# 'this-is-a-string'

# %% [markdown]
# join elements of b using space ' '

# %%
' '.join(b)
# Out:
# 'this is a string'

# %%
my_name="Pranav Patel"
my_split_name=my_name.split(' ')
print(my_split_name)
# Out:
# ['Pranav', 'Patel']

# %%
firstname_lastname=['Pranav','Patel']
fullname='-'.join(firstname_lastname)
print(fullname)
# Out:
# Pranav-Patel
