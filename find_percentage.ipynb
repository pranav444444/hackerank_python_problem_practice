# %% [markdown]
# The provided code stub will read in a dictionary containing key/value pairs of name:[marks] for a list of students. Print the average of the marks array for the student name provided, showing 2 places after the decimal.

# %%
my_dict={'Krishna':[67,76,88],'Arjun':[45,67,53],'Malika':[77,65,40]}
my_dict
# Out:
# {'Krishna': [67, 76, 88], 'Arjun': [45, 67, 53], 'Malika': [77, 65, 40]}

# %%
my_dict.keys()
# Out:
# dict_keys(['Krishna', 'Arjun', 'Malika'])

# %%
for key in my_dict.keys():
  print(key)
# Out:
# Krishna
# Arjun
# Malika

# %%
for value in my_dict.values():
  print(value)
# Out:
# [67, 76, 88]
# [45, 67, 53]
# [77, 65, 40]

# %%
for key,value in my_dict.items():
  print(key,value)
# Out:
# Krishna [67, 76, 88]
# Arjun [45, 67, 53]
# Malika [77, 65, 40]

# %%
sum(value)
# Out:
# 182

# %%
len(value)
# Out:
# 3

# %%
sum(value)/len(value)
# Out:
# 60.666666666666664

# %%
x=12.5627349
print(f"{x : .2f}")
# Out:
#  12.56

# %%
x=12.5627349
print(f"{x : .4f}")
# Out:
#  12.5627

# %%
for key,value in my_dict.items():
  average_two_decimal_scores=sum(value)/len(value)
  print(f"The average score of {key} is {average_two_decimal_scores:.2f}")
# Out:
# The average score of Krishna is 77.00
# The average score of Arjun is 55.00
# The average score of Malika is 60.67
