# %%
my_list=[67,45,33,42]

# %%
my_list[0]
# Out:
# 67

# %%
# Lists are mutable
my_list[0]=23

# %%
my_list[0]
# Out:
# 23

# %%
my_list
# Out:
# [23, 45, 33, 42]

# %%
#Tuples are immutable
my_tuple=(34,56,67,21)

# %%
my_tuple[0]
# Out:
# 34

# %%
my_tuple[0]=45 #error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 my_tuple[0]=45 #error
#
# TypeError: 'tuple' object does not support item assignment

# %%
#string are also immutable
my_sting="Pranav"

# %%
my_sting[0]
# Out:
# 'P'

# %%
my_sting[0]='S' #erorr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 my_sting[0]='S' #erorr
#
# TypeError: 'str' object does not support item assignment

# %%
string = "abracadabra"

# %%
print(string[5])
# Out:
# a

# %%
# we cna do this in 2 ways :

# %%
my_string_list=list(string)

# %%
my_string_list
# Out:
# ['a', 'b', 'r', 'a', 'c', 'a', 'd', 'a', 'b', 'r', 'a']

# %%
my_string_list[5]='k'

# %%
my_string_list
# Out:
# ['a', 'b', 'r', 'a', 'c', 'k', 'd', 'a', 'b', 'r', 'a']

# %%
new_string=''.join(my_sting_list)

# %%
new_string
# Out:
# 'abrackdabra'

# %%
#Another way is by slicing

# %%
string1="abracadabra"

# %%
string1[:5]
# Out:
# 'abrac'

# %%
string1[5]
# Out:
# 'a'

# %%
string1[6:]
# Out:
# 'dabra'

# %%
new_string_2=string1[:5]+"k"+string1[6:]
print(new_string_2)
# Out:
# abrackdabra
