# %%
arr=[2,3,6,6,6,5]

# %%
arr.sort(reverse=True)
print(arr)
# Out:
# [6, 6, 6, 5, 3, 2]

# %%
len(arr)
# Out:
# 6

# %%
for i in range(6):
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
arr
# Out:
# [6, 6, 6, 5, 3, 2]

# %%
for score in range(len(arr)):
  if arr[score] != arr[score+1]:
    runner_up=arr[score+1]
    break
  else: 
    continue
  
print(runner_up)
# Out:
# 5

# %%
max(arr)
# Out:
# 6
