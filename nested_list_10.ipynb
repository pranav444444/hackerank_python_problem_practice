# %%
my_list=[1,2,3,4,5]

# %%
my_list[0]
# Out:
# 1

# %%
my_nested_list=[[1,2],['a','b','c'],['Sam',25]]

# %%
my_nested_list[0]
# Out:
# [1, 2]

# %%
my_nested_list[1]
# Out:
# ['a', 'b', 'c']

# %%
my_nested_list[1][0]
# Out:
# 'a'

# %%
my_nested_list[1][1]
# Out:
# 'b'

# %% [markdown]
# Given the names and grades for each student in a class of  students, store them in a nested list and print the name(s) of any student(s) having the second lowest grade.
#
# Note: If there are multiple students with the second lowest grade, order their names alphabetically and print each name on a new line.

# %%
names_scores=[['Pranav',86],['Rahul',67],['Suresh',40]]

# %%
names_scores[1]
# Out:
# ['Rahul', 67]

# %%
names_scores[1][1]
# Out:
# 67

# %%
for students in names_scores:
  print(students)
# Out:
# ['Pranav', 86]
# ['Rahul', 67]
# ['Suresh', 40]

# %%
for students in names_scores:
  print(students[1])
# Out:
# 86
# 67
# 40

# %%
scores=[]
for students in names_scores:
  scores.append(students[1])

# %%
scores
# Out:
# [86, 67, 40]

# %%
names_scores_new=[['Pranav',86],['Suresh',40],['Himesh',76],['Tarun',67],['Manan',76],['Rahul',67]]

# %%
scores=[]
for students in names_scores_new:
  scores.append(students[1])

# %%
print(scores)
# Out:
# [86, 40, 76, 67, 76, 67]

# %% [markdown]
# sorting scores

# %%
#sorted_scores=sorted(scores)

# %%
#print(sorted_scores)

# %%
#using set as we want only unique scores
#sorted_scores=set(sorted_scores)

# %%
scores=[]
for students in names_scores_new:
  scores.append(students[1])
sorted_scores=sorted(set(scores))
second_lowest=sorted_scores[1]

# %%
print(sorted_scores)
# Out:
# [40, 67, 76, 86]

# %%
print(second_lowest)
# Out:
# 67

# %%
#now get the names
names_second_lowest=[]
for student in names_scores_new:
  if student[1]==second_lowest:
    names_second_lowest.append(student[0])
print(names_second_lowest)
# Out:
# ['Tarun', 'Rahul']

# %%
#but we were given instrucrion if 2 students have same second lowest score then sort them alphabeticallay ..
#now get the names
names_second_lowest=[]
for student in names_scores_new:
  if student[1]==second_lowest:
    names_second_lowest.append(student[0])
names_second_lowest=sorted(names_second_lowest)

# %%
for name in names_second_lowest:
  print(name)
# Out:
# Rahul
# Tarun
